# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)
# Out:
# (768, 10)

# %%
print('Shape of the dataframe: {}'.format(df.shape))
print('Shape of the training set: {}'.format(train.shape))
print('Shape of the test set: {}'.format(test.shape))
# Out:
# Shape of the dataframe: (768, 10)
# Shape of the training set: (614, 8)
# Shape of the test set: (154, 8)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train.columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          1152        input_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          16512       dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           8256        dense_4[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_4[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_5[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 257.2463 - y1_output_loss: 118.2654 - y2_output_loss: 136.7635 - y1_output_root_mean_squared_error: 10.9222 - y2_output_root_mean_squared_error: 11.7453 - val_loss: 35.3634 - val_y1_output_loss: 17.4374 - val_y2_output_loss: 18.7662 - val_y1_output_root_mean_squared_error: 4.0836 - val_y2_output_root_mean_squared_error: 4.3229
# Epoch 2/500
# 614/614 [==============================] - 0s 168us/sample - loss: 36.4083 - y1_output_loss: 13.3545 - y2_output_loss: 22.8598 - y1_output_root_mean_squared_error: 3.6621 - y2_output_root_mean_squared_error: 4.7955 - val_loss: 26.1178 - val_y1_output_loss: 12.6239 - val_y2_output_loss: 14.2922 - val_y1_output_root_mean_squared_error: 3.4592 - val_y2_output_root_mean_squared_error: 3.7619
# Epoch 3/500
# 614/614 [==============================] - 0s 142us/sample - loss: 25.5322 - y1_output_loss: 10.3299 - y2_output_loss: 15.5564 - y1_output_root_mean_squared_error: 3.1740 - y2_output_root_mean_squared_error: 3.9317 - val_loss: 70.2476 - val_y1_output_loss: 22.8513 - val_y2_output_loss: 48.8339 - val_y1_output_root_mean_squared_error: 4.6776 - val_y2_output_root_mean_squared_error: 6.9547
# Epoch 4/500
# 614/614 [==============================] - 0s 154us/sample - loss: 24.7913 - y1_output_loss: 9.4812 - y2_output_loss: 15.0981 - y1_output_root_mean_squared_error: 3.0910 - y2_output_root_mean_squared_error: 3.9035 - val_loss: 24.5687 - val_y1_output_loss: 12.1912 - val_y2_output_loss: 13.0478 - val_y1_output_root_mean_squared_error: 3.4217 - val_y2_output_root_mean_squared_error: 3.5862
# Epoch 5/500
# 614/614 [==============================] - 0s 157us/sample - loss: 24.0034 - y1_output_loss: 9.0498 - y2_output_loss: 14.8431 - y1_output_root_mean_squared_error: 3.0191 - y2_output_root_mean_squared_error: 3.8586 - val_loss: 22.5930 - val_y1_output_loss: 10.2670 - val_y2_output_loss: 12.8987 - val_y1_output_root_mean_squared_error: 3.1431 - val_y2_output_root_mean_squared_error: 3.5656
# Epoch 6/500
# 614/614 [==============================] - 0s 139us/sample - loss: 22.7942 - y1_output_loss: 8.8127 - y2_output_loss: 13.8355 - y1_output_root_mean_squared_error: 2.9824 - y2_output_root_mean_squared_error: 3.7282 - val_loss: 35.6830 - val_y1_output_loss: 13.7382 - val_y2_output_loss: 23.3658 - val_y1_output_root_mean_squared_error: 3.6368 - val_y2_output_root_mean_squared_error: 4.7388
# Epoch 7/500
# 614/614 [==============================] - 0s 138us/sample - loss: 21.9508 - y1_output_loss: 8.4951 - y2_output_loss: 13.4000 - y1_output_root_mean_squared_error: 2.9137 - y2_output_root_mean_squared_error: 3.6689 - val_loss: 26.9357 - val_y1_output_loss: 12.2930 - val_y2_output_loss: 15.5203 - val_y1_output_root_mean_squared_error: 3.3979 - val_y2_output_root_mean_squared_error: 3.9230
# Epoch 8/500
# 614/614 [==============================] - 0s 138us/sample - loss: 21.7649 - y1_output_loss: 8.1915 - y2_output_loss: 13.4525 - y1_output_root_mean_squared_error: 2.8610 - y2_output_root_mean_squared_error: 3.6851 - val_loss: 24.2000 - val_y1_output_loss: 11.7746 - val_y2_output_loss: 12.8919 - val_y1_output_root_mean_squared_error: 3.3844 - val_y2_output_root_mean_squared_error: 3.5701
# Epoch 9/500
# 614/614 [==============================] - 0s 143us/sample - loss: 22.3434 - y1_output_loss: 8.6715 - y2_output_loss: 13.7531 - y1_output_root_mean_squared_error: 2.9315 - y2_output_root_mean_squared_error: 3.7080 - val_loss: 27.1066 - val_y1_output_loss: 11.8081 - val_y2_output_loss: 16.2476 - val_y1_output_root_mean_squared_error: 3.3636 - val_y2_output_root_mean_squared_error: 3.9740
# Epoch 10/500
# 614/614 [==============================] - 0s 136us/sample - loss: 21.2058 - y1_output_loss: 8.2669 - y2_output_loss: 12.8979 - y1_output_root_mean_squared_error: 2.8784 - y2_output_root_mean_squared_error: 3.5945 - val_loss: 31.0726 - val_y1_output_loss: 12.4255 - val_y2_output_loss: 19.3538 - val_y1_output_root_mean_squared_error: 3.4298 - val_y2_output_root_mean_squared_error: 4.3942
# Epoch 11/500
# 614/614 [==============================] - 0s 136us/sample - loss: 20.0477 - y1_output_loss: 8.0350 - y2_output_loss: 12.4202 - y1_output_root_mean_squared_error: 2.8288 - y2_output_root_mean_squared_error: 3.4707 - val_loss: 73.1401 - val_y1_output_loss: 20.1572 - val_y2_output_loss: 55.7112 - val_y1_output_root_mean_squared_error: 4.4326 - val_y2_output_root_mean_squared_error: 7.3138
# Epoch 12/500
# 614/614 [==============================] - 0s 131us/sample - loss: 17.5958 - y1_output_loss: 7.2672 - y2_output_loss: 10.3237 - y1_output_root_mean_squared_error: 2.6893 - y2_output_root_mean_squared_error: 3.2192 - val_loss: 39.6999 - val_y1_output_loss: 15.4570 - val_y2_output_loss: 24.8800 - val_y1_output_root_mean_squared_error: 3.8517 - val_y2_output_root_mean_squared_error: 4.9864
# Epoch 13/500
# 614/614 [==============================] - 0s 131us/sample - loss: 18.8404 - y1_output_loss: 7.1757 - y2_output_loss: 11.5800 - y1_output_root_mean_squared_error: 2.6882 - y2_output_root_mean_squared_error: 3.4079 - val_loss: 27.9821 - val_y1_output_loss: 10.7961 - val_y2_output_loss: 18.3603 - val_y1_output_root_mean_squared_error: 3.2071 - val_y2_output_root_mean_squared_error: 4.2067
# Epoch 14/500
# 614/614 [==============================] - 0s 136us/sample - loss: 18.1881 - y1_output_loss: 6.8863 - y2_output_loss: 11.5164 - y1_output_root_mean_squared_error: 2.6113 - y2_output_root_mean_squared_error: 3.3718 - val_loss: 23.5264 - val_y1_output_loss: 9.6124 - val_y2_output_loss: 15.0331 - val_y1_output_root_mean_squared_error: 3.0141 - val_y2_output_root_mean_squared_error: 3.8002
# Epoch 15/500
# 614/614 [==============================] - 0s 136us/sample - loss: 17.8333 - y1_output_loss: 6.9540 - y2_output_loss: 10.9806 - y1_output_root_mean_squared_error: 2.6287 - y2_output_root_mean_squared_error: 3.3050 - val_loss: 23.1829 - val_y1_output_loss: 9.8958 - val_y2_output_loss: 13.7561 - val_y1_output_root_mean_squared_error: 3.0633 - val_y2_output_root_mean_squared_error: 3.7148
# Epoch 16/500
# 614/614 [==============================] - 0s 133us/sample - loss: 17.1961 - y1_output_loss: 6.7054 - y2_output_loss: 10.3654 - y1_output_root_mean_squared_error: 2.6000 - y2_output_root_mean_squared_error: 3.2305 - val_loss: 16.6677 - val_y1_output_loss: 7.7676 - val_y2_output_loss: 9.3519 - val_y1_output_root_mean_squared_error: 2.7301 - val_y2_output_root_mean_squared_error: 3.0355
# Epoch 17/500
# 614/614 [==============================] - 0s 136us/sample - loss: 17.0704 - y1_output_loss: 6.2251 - y2_output_loss: 10.7502 - y1_output_root_mean_squared_error: 2.5065 - y2_output_root_mean_squared_error: 3.2845 - val_loss: 15.9690 - val_y1_output_loss: 7.4600 - val_y2_output_loss: 9.1248 - val_y1_output_root_mean_squared_error: 2.6687 - val_y2_output_root_mean_squared_error: 2.9744
# Epoch 18/500
# 614/614 [==============================] - 0s 138us/sample - loss: 21.7729 - y1_output_loss: 7.4367 - y2_output_loss: 14.4668 - y1_output_root_mean_squared_error: 2.7247 - y2_output_root_mean_squared_error: 3.7880 - val_loss: 25.9323 - val_y1_output_loss: 9.8658 - val_y2_output_loss: 16.4658 - val_y1_output_root_mean_squared_error: 3.0613 - val_y2_output_root_mean_squared_error: 4.0695
# Epoch 19/500
# 614/614 [==============================] - 0s 140us/sample - loss: 14.2503 - y1_output_loss: 5.7833 - y2_output_loss: 8.9326 - y1_output_root_mean_squared_error: 2.3918 - y2_output_root_mean_squared_error: 2.9205 - val_loss: 42.0796 - val_y1_output_loss: 8.4537 - val_y2_output_loss: 35.1054 - val_y1_output_root_mean_squared_error: 2.8733 - val_y2_output_root_mean_squared_error: 5.8158
# Epoch 20/500
# 614/614 [==============================] - 0s 151us/sample - loss: 16.3082 - y1_output_loss: 5.9381 - y2_output_loss: 10.2305 - y1_output_root_mean_squared_error: 2.4456 - y2_output_root_mean_squared_error: 3.2136 - val_loss: 13.6232 - val_y1_output_loss: 6.3370 - val_y2_output_loss: 7.5791 - val_y1_output_root_mean_squared_error: 2.4759 - val_y2_output_root_mean_squared_error: 2.7374
# Epoch 21/500
# 614/614 [==============================] - 0s 137us/sample - loss: 15.0416 - y1_output_loss: 5.7008 - y2_output_loss: 9.2712 - y1_output_root_mean_squared_error: 2.3941 - y2_output_root_mean_squared_error: 3.0512 - val_loss: 18.1121 - val_y1_output_loss: 8.2458 - val_y2_output_loss: 10.5094 - val_y1_output_root_mean_squared_error: 2.8260 - val_y2_output_root_mean_squared_error: 3.1821
# Epoch 22/500
# 614/614 [==============================] - 0s 143us/sample - loss: 13.3527 - y1_output_loss: 5.1167 - y2_output_loss: 8.3149 - y1_output_root_mean_squared_error: 2.2517 - y2_output_root_mean_squared_error: 2.8779 - val_loss: 26.4292 - val_y1_output_loss: 9.2949 - val_y2_output_loss: 17.3046 - val_y1_output_root_mean_squared_error: 2.9981 - val_y2_output_root_mean_squared_error: 4.1762
# Epoch 23/500
# 614/614 [==============================] - 0s 134us/sample - loss: 12.4670 - y1_output_loss: 5.0239 - y2_output_loss: 7.3467 - y1_output_root_mean_squared_error: 2.2515 - y2_output_root_mean_squared_error: 2.7199 - val_loss: 13.7661 - val_y1_output_loss: 6.2949 - val_y2_output_loss: 7.6737 - val_y1_output_root_mean_squared_error: 2.4559 - val_y2_output_root_mean_squared_error: 2.7812
# Epoch 24/500
# 614/614 [==============================] - 0s 135us/sample - loss: 15.6433 - y1_output_loss: 5.5567 - y2_output_loss: 9.9996 - y1_output_root_mean_squared_error: 2.3614 - y2_output_root_mean_squared_error: 3.1729 - val_loss: 13.2614 - val_y1_output_loss: 5.9711 - val_y2_output_loss: 7.5146 - val_y1_output_root_mean_squared_error: 2.4000 - val_y2_output_root_mean_squared_error: 2.7389
# Epoch 25/500
# 614/614 [==============================] - 0s 133us/sample - loss: 12.1497 - y1_output_loss: 4.6070 - y2_output_loss: 7.5302 - y1_output_root_mean_squared_error: 2.1541 - y2_output_root_mean_squared_error: 2.7403 - val_loss: 13.4850 - val_y1_output_loss: 6.3975 - val_y2_output_loss: 7.5720 - val_y1_output_root_mean_squared_error: 2.4712 - val_y2_output_root_mean_squared_error: 2.7163
# Epoch 26/500
# 614/614 [==============================] - 0s 136us/sample - loss: 10.8813 - y1_output_loss: 4.3286 - y2_output_loss: 6.4658 - y1_output_root_mean_squared_error: 2.0893 - y2_output_root_mean_squared_error: 2.5527 - val_loss: 12.9861 - val_y1_output_loss: 6.1037 - val_y2_output_loss: 7.2833 - val_y1_output_root_mean_squared_error: 2.4261 - val_y2_output_root_mean_squared_error: 2.6646
# Epoch 27/500
# 614/614 [==============================] - 0s 147us/sample - loss: 14.3410 - y1_output_loss: 5.1783 - y2_output_loss: 9.1475 - y1_output_root_mean_squared_error: 2.2718 - y2_output_root_mean_squared_error: 3.0298 - val_loss: 17.6113 - val_y1_output_loss: 6.6529 - val_y2_output_loss: 10.9175 - val_y1_output_root_mean_squared_error: 2.5537 - val_y2_output_root_mean_squared_error: 3.3302
# Epoch 28/500
# 614/614 [==============================] - 0s 134us/sample - loss: 13.1699 - y1_output_loss: 4.5960 - y2_output_loss: 8.4911 - y1_output_root_mean_squared_error: 2.1470 - y2_output_root_mean_squared_error: 2.9258 - val_loss: 14.0451 - val_y1_output_loss: 5.7239 - val_y2_output_loss: 8.9238 - val_y1_output_root_mean_squared_error: 2.3405 - val_y2_output_root_mean_squared_error: 2.9270
# Epoch 29/500
# 614/614 [==============================] - 0s 136us/sample - loss: 11.4981 - y1_output_loss: 4.3044 - y2_output_loss: 7.1950 - y1_output_root_mean_squared_error: 2.0778 - y2_output_root_mean_squared_error: 2.6797 - val_loss: 21.7932 - val_y1_output_loss: 6.7265 - val_y2_output_loss: 16.0058 - val_y1_output_root_mean_squared_error: 2.5608 - val_y2_output_root_mean_squared_error: 3.9033
# Epoch 30/500
# 614/614 [==============================] - 0s 131us/sample - loss: 12.6211 - y1_output_loss: 4.4107 - y2_output_loss: 8.3445 - y1_output_root_mean_squared_error: 2.0787 - y2_output_root_mean_squared_error: 2.8810 - val_loss: 30.8451 - val_y1_output_loss: 10.1311 - val_y2_output_loss: 20.7373 - val_y1_output_root_mean_squared_error: 3.1400 - val_y2_output_root_mean_squared_error: 4.5810
# Epoch 31/500
# 614/614 [==============================] - 0s 134us/sample - loss: 11.0805 - y1_output_loss: 4.2076 - y2_output_loss: 6.8277 - y1_output_root_mean_squared_error: 2.0512 - y2_output_root_mean_squared_error: 2.6217 - val_loss: 17.8459 - val_y1_output_loss: 6.7377 - val_y2_output_loss: 11.0403 - val_y1_output_root_mean_squared_error: 2.5662 - val_y2_output_root_mean_squared_error: 3.3556
# Epoch 32/500
# 614/614 [==============================] - 0s 135us/sample - loss: 10.9899 - y1_output_loss: 3.9794 - y2_output_loss: 7.0463 - y1_output_root_mean_squared_error: 1.9877 - y2_output_root_mean_squared_error: 2.6531 - val_loss: 14.7956 - val_y1_output_loss: 4.7427 - val_y2_output_loss: 9.9760 - val_y1_output_root_mean_squared_error: 2.1428 - val_y2_output_root_mean_squared_error: 3.1944
# Epoch 33/500
# 614/614 [==============================] - 0s 133us/sample - loss: 12.3154 - y1_output_loss: 4.1137 - y2_output_loss: 8.1686 - y1_output_root_mean_squared_error: 2.0231 - y2_output_root_mean_squared_error: 2.8675 - val_loss: 13.3329 - val_y1_output_loss: 5.1113 - val_y2_output_loss: 8.1278 - val_y1_output_root_mean_squared_error: 2.2418 - val_y2_output_root_mean_squared_error: 2.8822
# Epoch 34/500
# 614/614 [==============================] - 0s 131us/sample - loss: 27.0765 - y1_output_loss: 8.0390 - y2_output_loss: 18.8206 - y1_output_root_mean_squared_error: 2.8427 - y2_output_root_mean_squared_error: 4.3584 - val_loss: 11.3983 - val_y1_output_loss: 3.9534 - val_y2_output_loss: 7.9146 - val_y1_output_root_mean_squared_error: 1.9558 - val_y2_output_root_mean_squared_error: 2.7519
# Epoch 35/500
# 614/614 [==============================] - 0s 142us/sample - loss: 9.7682 - y1_output_loss: 3.4430 - y2_output_loss: 6.2917 - y1_output_root_mean_squared_error: 1.8643 - y2_output_root_mean_squared_error: 2.5085 - val_loss: 14.4706 - val_y1_output_loss: 4.7915 - val_y2_output_loss: 10.1626 - val_y1_output_root_mean_squared_error: 2.1585 - val_y2_output_root_mean_squared_error: 3.1323
# Epoch 36/500
# 614/614 [==============================] - 0s 130us/sample - loss: 10.3476 - y1_output_loss: 3.6408 - y2_output_loss: 6.6391 - y1_output_root_mean_squared_error: 1.9151 - y2_output_root_mean_squared_error: 2.5846 - val_loss: 12.9997 - val_y1_output_loss: 4.1582 - val_y2_output_loss: 9.5445 - val_y1_output_root_mean_squared_error: 2.0038 - val_y2_output_root_mean_squared_error: 2.9974
# Epoch 37/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.0881 - y1_output_loss: 3.3455 - y2_output_loss: 6.6867 - y1_output_root_mean_squared_error: 1.8271 - y2_output_root_mean_squared_error: 2.5980 - val_loss: 8.5458 - val_y1_output_loss: 3.5149 - val_y2_output_loss: 5.2674 - val_y1_output_root_mean_squared_error: 1.8490 - val_y2_output_root_mean_squared_error: 2.2643
# Epoch 38/500
# 614/614 [==============================] - 0s 135us/sample - loss: 9.3293 - y1_output_loss: 3.3728 - y2_output_loss: 5.9550 - y1_output_root_mean_squared_error: 1.8314 - y2_output_root_mean_squared_error: 2.4445 - val_loss: 9.8058 - val_y1_output_loss: 3.7172 - val_y2_output_loss: 6.0839 - val_y1_output_root_mean_squared_error: 1.9119 - val_y2_output_root_mean_squared_error: 2.4800
# Epoch 39/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.2545 - y1_output_loss: 2.9554 - y2_output_loss: 5.3312 - y1_output_root_mean_squared_error: 1.7214 - y2_output_root_mean_squared_error: 2.3003 - val_loss: 10.5688 - val_y1_output_loss: 3.3058 - val_y2_output_loss: 7.6982 - val_y1_output_root_mean_squared_error: 1.8001 - val_y2_output_root_mean_squared_error: 2.7071
# Epoch 40/500
# 614/614 [==============================] - 0s 136us/sample - loss: 10.2465 - y1_output_loss: 3.4374 - y2_output_loss: 6.8116 - y1_output_root_mean_squared_error: 1.8504 - y2_output_root_mean_squared_error: 2.6120 - val_loss: 8.7945 - val_y1_output_loss: 3.4418 - val_y2_output_loss: 5.6501 - val_y1_output_root_mean_squared_error: 1.8306 - val_y2_output_root_mean_squared_error: 2.3331
# Epoch 41/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.2130 - y1_output_loss: 2.7046 - y2_output_loss: 5.5903 - y1_output_root_mean_squared_error: 1.6465 - y2_output_root_mean_squared_error: 2.3456 - val_loss: 14.5442 - val_y1_output_loss: 4.0276 - val_y2_output_loss: 11.1776 - val_y1_output_root_mean_squared_error: 1.9876 - val_y2_output_root_mean_squared_error: 3.2548
# Epoch 42/500
# 614/614 [==============================] - 0s 134us/sample - loss: 10.9135 - y1_output_loss: 3.6260 - y2_output_loss: 7.2238 - y1_output_root_mean_squared_error: 1.9089 - y2_output_root_mean_squared_error: 2.6962 - val_loss: 7.6315 - val_y1_output_loss: 2.8892 - val_y2_output_loss: 4.9344 - val_y1_output_root_mean_squared_error: 1.6883 - val_y2_output_root_mean_squared_error: 2.1866
# Epoch 43/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.4058 - y1_output_loss: 3.1536 - y2_output_loss: 6.2189 - y1_output_root_mean_squared_error: 1.7789 - y2_output_root_mean_squared_error: 2.4983 - val_loss: 13.2845 - val_y1_output_loss: 4.0788 - val_y2_output_loss: 10.0315 - val_y1_output_root_mean_squared_error: 1.9695 - val_y2_output_root_mean_squared_error: 3.0668
# Epoch 44/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.4481 - y1_output_loss: 2.6677 - y2_output_loss: 4.7286 - y1_output_root_mean_squared_error: 1.6359 - y2_output_root_mean_squared_error: 2.1845 - val_loss: 7.7768 - val_y1_output_loss: 2.9102 - val_y2_output_loss: 4.8750 - val_y1_output_root_mean_squared_error: 1.7081 - val_y2_output_root_mean_squared_error: 2.2043
# Epoch 45/500
# 614/614 [==============================] - 0s 145us/sample - loss: 8.6146 - y1_output_loss: 2.8822 - y2_output_loss: 5.7196 - y1_output_root_mean_squared_error: 1.6921 - y2_output_root_mean_squared_error: 2.3982 - val_loss: 8.0612 - val_y1_output_loss: 2.7459 - val_y2_output_loss: 5.2350 - val_y1_output_root_mean_squared_error: 1.6632 - val_y2_output_root_mean_squared_error: 2.3011
# Epoch 46/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.0535 - y1_output_loss: 2.4268 - y2_output_loss: 4.5693 - y1_output_root_mean_squared_error: 1.5650 - y2_output_root_mean_squared_error: 2.1458 - val_loss: 7.5140 - val_y1_output_loss: 2.6589 - val_y2_output_loss: 4.8248 - val_y1_output_root_mean_squared_error: 1.6344 - val_y2_output_root_mean_squared_error: 2.2006
# Epoch 47/500
# 614/614 [==============================] - 0s 141us/sample - loss: 7.6072 - y1_output_loss: 2.5491 - y2_output_loss: 4.9973 - y1_output_root_mean_squared_error: 1.6022 - y2_output_root_mean_squared_error: 2.2450 - val_loss: 8.1854 - val_y1_output_loss: 2.5886 - val_y2_output_loss: 5.8940 - val_y1_output_root_mean_squared_error: 1.6000 - val_y2_output_root_mean_squared_error: 2.3718
# Epoch 48/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.4512 - y1_output_loss: 2.5564 - y2_output_loss: 4.8432 - y1_output_root_mean_squared_error: 1.6044 - y2_output_root_mean_squared_error: 2.2084 - val_loss: 7.1213 - val_y1_output_loss: 2.4730 - val_y2_output_loss: 4.8556 - val_y1_output_root_mean_squared_error: 1.5618 - val_y2_output_root_mean_squared_error: 2.1638
# Epoch 49/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.4111 - y1_output_loss: 2.4550 - y2_output_loss: 4.9114 - y1_output_root_mean_squared_error: 1.5684 - y2_output_root_mean_squared_error: 2.2251 - val_loss: 8.7707 - val_y1_output_loss: 2.8392 - val_y2_output_loss: 5.7636 - val_y1_output_root_mean_squared_error: 1.6834 - val_y2_output_root_mean_squared_error: 2.4366
# Epoch 50/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.8820 - y1_output_loss: 2.3376 - y2_output_loss: 4.4869 - y1_output_root_mean_squared_error: 1.5339 - y2_output_root_mean_squared_error: 2.1282 - val_loss: 7.7979 - val_y1_output_loss: 2.5924 - val_y2_output_loss: 5.3840 - val_y1_output_root_mean_squared_error: 1.6125 - val_y2_output_root_mean_squared_error: 2.2799
# Epoch 51/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.4604 - y1_output_loss: 2.3552 - y2_output_loss: 5.0605 - y1_output_root_mean_squared_error: 1.5352 - y2_output_root_mean_squared_error: 2.2591 - val_loss: 7.6737 - val_y1_output_loss: 2.7645 - val_y2_output_loss: 4.8202 - val_y1_output_root_mean_squared_error: 1.6706 - val_y2_output_root_mean_squared_error: 2.2097
# Epoch 52/500
# 614/614 [==============================] - 0s 147us/sample - loss: 9.0599 - y1_output_loss: 2.8992 - y2_output_loss: 6.1222 - y1_output_root_mean_squared_error: 1.7063 - y2_output_root_mean_squared_error: 2.4796 - val_loss: 8.0776 - val_y1_output_loss: 2.3194 - val_y2_output_loss: 5.6147 - val_y1_output_root_mean_squared_error: 1.5181 - val_y2_output_root_mean_squared_error: 2.4027
# Epoch 53/500
# 614/614 [==============================] - 0s 138us/sample - loss: 8.6577 - y1_output_loss: 2.6867 - y2_output_loss: 6.0087 - y1_output_root_mean_squared_error: 1.6203 - y2_output_root_mean_squared_error: 2.4561 - val_loss: 9.2510 - val_y1_output_loss: 4.2791 - val_y2_output_loss: 4.9135 - val_y1_output_root_mean_squared_error: 2.0684 - val_y2_output_root_mean_squared_error: 2.2299
# Epoch 54/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.4282 - y1_output_loss: 2.7415 - y2_output_loss: 5.6797 - y1_output_root_mean_squared_error: 1.6489 - y2_output_root_mean_squared_error: 2.3894 - val_loss: 11.3318 - val_y1_output_loss: 4.1262 - val_y2_output_loss: 7.6051 - val_y1_output_root_mean_squared_error: 2.0225 - val_y2_output_root_mean_squared_error: 2.6910
# Epoch 55/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.9264 - y1_output_loss: 2.7904 - y2_output_loss: 5.1980 - y1_output_root_mean_squared_error: 1.6636 - y2_output_root_mean_squared_error: 2.2713 - val_loss: 9.0852 - val_y1_output_loss: 3.2336 - val_y2_output_loss: 5.7140 - val_y1_output_root_mean_squared_error: 1.8136 - val_y2_output_root_mean_squared_error: 2.4075
# Epoch 56/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.8266 - y1_output_loss: 2.3611 - y2_output_loss: 5.4071 - y1_output_root_mean_squared_error: 1.5428 - y2_output_root_mean_squared_error: 2.3338 - val_loss: 7.3580 - val_y1_output_loss: 2.2420 - val_y2_output_loss: 5.0138 - val_y1_output_root_mean_squared_error: 1.5054 - val_y2_output_root_mean_squared_error: 2.2565
# Epoch 57/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.2224 - y1_output_loss: 2.1617 - y2_output_loss: 4.0533 - y1_output_root_mean_squared_error: 1.4623 - y2_output_root_mean_squared_error: 2.0209 - val_loss: 6.4608 - val_y1_output_loss: 2.3443 - val_y2_output_loss: 4.1032 - val_y1_output_root_mean_squared_error: 1.5453 - val_y2_output_root_mean_squared_error: 2.0181
# Epoch 58/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.8295 - y1_output_loss: 2.2992 - y2_output_loss: 4.5407 - y1_output_root_mean_squared_error: 1.5214 - y2_output_root_mean_squared_error: 2.1248 - val_loss: 29.1571 - val_y1_output_loss: 5.5637 - val_y2_output_loss: 25.1677 - val_y1_output_root_mean_squared_error: 2.3263 - val_y2_output_root_mean_squared_error: 4.8729
# Epoch 59/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.6824 - y1_output_loss: 2.4060 - y2_output_loss: 5.2615 - y1_output_root_mean_squared_error: 1.5532 - y2_output_root_mean_squared_error: 2.2956 - val_loss: 6.5831 - val_y1_output_loss: 2.2288 - val_y2_output_loss: 4.3111 - val_y1_output_root_mean_squared_error: 1.5115 - val_y2_output_root_mean_squared_error: 2.0733
# Epoch 60/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.1551 - y1_output_loss: 2.3336 - y2_output_loss: 4.7564 - y1_output_root_mean_squared_error: 1.5342 - y2_output_root_mean_squared_error: 2.1912 - val_loss: 6.6539 - val_y1_output_loss: 2.2528 - val_y2_output_loss: 4.3227 - val_y1_output_root_mean_squared_error: 1.5165 - val_y2_output_root_mean_squared_error: 2.0867
# Epoch 61/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.6518 - y1_output_loss: 2.0163 - y2_output_loss: 3.6494 - y1_output_root_mean_squared_error: 1.4129 - y2_output_root_mean_squared_error: 1.9120 - val_loss: 9.1212 - val_y1_output_loss: 2.8269 - val_y2_output_loss: 6.1085 - val_y1_output_root_mean_squared_error: 1.6974 - val_y2_output_root_mean_squared_error: 2.4980
# Epoch 62/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.1477 - y1_output_loss: 2.2215 - y2_output_loss: 4.9925 - y1_output_root_mean_squared_error: 1.4873 - y2_output_root_mean_squared_error: 2.2216 - val_loss: 8.6251 - val_y1_output_loss: 3.0655 - val_y2_output_loss: 5.5266 - val_y1_output_root_mean_squared_error: 1.7614 - val_y2_output_root_mean_squared_error: 2.3500
# Epoch 63/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.9204 - y1_output_loss: 2.4886 - y2_output_loss: 4.4221 - y1_output_root_mean_squared_error: 1.5742 - y2_output_root_mean_squared_error: 2.1076 - val_loss: 10.7770 - val_y1_output_loss: 4.4829 - val_y2_output_loss: 6.3474 - val_y1_output_root_mean_squared_error: 2.1296 - val_y2_output_root_mean_squared_error: 2.4984
# Epoch 64/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.8946 - y1_output_loss: 2.0500 - y2_output_loss: 3.8217 - y1_output_root_mean_squared_error: 1.4378 - y2_output_root_mean_squared_error: 1.9563 - val_loss: 6.5880 - val_y1_output_loss: 2.0344 - val_y2_output_loss: 4.7861 - val_y1_output_root_mean_squared_error: 1.4296 - val_y2_output_root_mean_squared_error: 2.1317
# Epoch 65/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.2073 - y1_output_loss: 2.2672 - y2_output_loss: 4.9195 - y1_output_root_mean_squared_error: 1.5073 - y2_output_root_mean_squared_error: 2.2216 - val_loss: 7.1998 - val_y1_output_loss: 2.1293 - val_y2_output_loss: 5.3498 - val_y1_output_root_mean_squared_error: 1.4536 - val_y2_output_root_mean_squared_error: 2.2554
# Epoch 66/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.3760 - y1_output_loss: 2.0407 - y2_output_loss: 4.2742 - y1_output_root_mean_squared_error: 1.4354 - y2_output_root_mean_squared_error: 2.0774 - val_loss: 7.2199 - val_y1_output_loss: 2.1351 - val_y2_output_loss: 4.9334 - val_y1_output_root_mean_squared_error: 1.4671 - val_y2_output_root_mean_squared_error: 2.2512
# Epoch 67/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.7303 - y1_output_loss: 1.8976 - y2_output_loss: 3.8967 - y1_output_root_mean_squared_error: 1.3688 - y2_output_root_mean_squared_error: 1.9638 - val_loss: 10.5724 - val_y1_output_loss: 2.5776 - val_y2_output_loss: 8.4823 - val_y1_output_root_mean_squared_error: 1.5923 - val_y2_output_root_mean_squared_error: 2.8350
# Epoch 68/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.7234 - y1_output_loss: 1.9450 - y2_output_loss: 3.8596 - y1_output_root_mean_squared_error: 1.3803 - y2_output_root_mean_squared_error: 1.9540 - val_loss: 12.2449 - val_y1_output_loss: 4.2226 - val_y2_output_loss: 7.8318 - val_y1_output_root_mean_squared_error: 2.0633 - val_y2_output_root_mean_squared_error: 2.8263
# Epoch 69/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.2223 - y1_output_loss: 2.2725 - y2_output_loss: 4.9554 - y1_output_root_mean_squared_error: 1.5090 - y2_output_root_mean_squared_error: 2.2238 - val_loss: 10.8692 - val_y1_output_loss: 3.4920 - val_y2_output_loss: 7.7152 - val_y1_output_root_mean_squared_error: 1.8574 - val_y2_output_root_mean_squared_error: 2.7238
# Epoch 70/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.0043 - y1_output_loss: 2.5273 - y2_output_loss: 5.4645 - y1_output_root_mean_squared_error: 1.5949 - y2_output_root_mean_squared_error: 2.3368 - val_loss: 9.7940 - val_y1_output_loss: 2.6701 - val_y2_output_loss: 7.5019 - val_y1_output_root_mean_squared_error: 1.6280 - val_y2_output_root_mean_squared_error: 2.6728
# Epoch 71/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.0474 - y1_output_loss: 2.2967 - y2_output_loss: 5.6760 - y1_output_root_mean_squared_error: 1.5223 - y2_output_root_mean_squared_error: 2.3938 - val_loss: 5.1469 - val_y1_output_loss: 1.6927 - val_y2_output_loss: 3.4819 - val_y1_output_root_mean_squared_error: 1.3080 - val_y2_output_root_mean_squared_error: 1.8536
# Epoch 72/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.7378 - y1_output_loss: 2.4664 - y2_output_loss: 5.2161 - y1_output_root_mean_squared_error: 1.5740 - y2_output_root_mean_squared_error: 2.2936 - val_loss: 7.0079 - val_y1_output_loss: 2.4726 - val_y2_output_loss: 4.7947 - val_y1_output_root_mean_squared_error: 1.5719 - val_y2_output_root_mean_squared_error: 2.1301
# Epoch 73/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.3226 - y1_output_loss: 1.5898 - y2_output_loss: 3.7068 - y1_output_root_mean_squared_error: 1.2598 - y2_output_root_mean_squared_error: 1.9328 - val_loss: 7.4678 - val_y1_output_loss: 2.2906 - val_y2_output_loss: 5.5373 - val_y1_output_root_mean_squared_error: 1.4944 - val_y2_output_root_mean_squared_error: 2.2879
# Epoch 74/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.7704 - y1_output_loss: 1.9641 - y2_output_loss: 4.7663 - y1_output_root_mean_squared_error: 1.4065 - y2_output_root_mean_squared_error: 2.1891 - val_loss: 10.8502 - val_y1_output_loss: 2.3414 - val_y2_output_loss: 8.3209 - val_y1_output_root_mean_squared_error: 1.5383 - val_y2_output_root_mean_squared_error: 2.9127
# Epoch 75/500
# 614/614 [==============================] - 0s 148us/sample - loss: 5.0661 - y1_output_loss: 1.6065 - y2_output_loss: 3.4132 - y1_output_root_mean_squared_error: 1.2732 - y2_output_root_mean_squared_error: 1.8561 - val_loss: 6.3862 - val_y1_output_loss: 1.8605 - val_y2_output_loss: 4.8357 - val_y1_output_root_mean_squared_error: 1.3525 - val_y2_output_root_mean_squared_error: 2.1347
# Epoch 76/500
# 614/614 [==============================] - 0s 150us/sample - loss: 5.4341 - y1_output_loss: 1.7426 - y2_output_loss: 3.6502 - y1_output_root_mean_squared_error: 1.3243 - y2_output_root_mean_squared_error: 1.9185 - val_loss: 4.3927 - val_y1_output_loss: 1.2571 - val_y2_output_loss: 3.1178 - val_y1_output_root_mean_squared_error: 1.1228 - val_y2_output_root_mean_squared_error: 1.7697
# Epoch 77/500
# 614/614 [==============================] - 0s 148us/sample - loss: 4.8293 - y1_output_loss: 1.3262 - y2_output_loss: 3.5104 - y1_output_root_mean_squared_error: 1.1530 - y2_output_root_mean_squared_error: 1.8708 - val_loss: 7.0358 - val_y1_output_loss: 1.5980 - val_y2_output_loss: 5.8022 - val_y1_output_root_mean_squared_error: 1.2561 - val_y2_output_root_mean_squared_error: 2.3363
# Epoch 78/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.6425 - y1_output_loss: 1.3524 - y2_output_loss: 3.3021 - y1_output_root_mean_squared_error: 1.1646 - y2_output_root_mean_squared_error: 1.8128 - val_loss: 7.9757 - val_y1_output_loss: 1.5490 - val_y2_output_loss: 6.3211 - val_y1_output_root_mean_squared_error: 1.2454 - val_y2_output_root_mean_squared_error: 2.5347
# Epoch 79/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.1890 - y1_output_loss: 1.4036 - y2_output_loss: 3.7563 - y1_output_root_mean_squared_error: 1.1837 - y2_output_root_mean_squared_error: 1.9462 - val_loss: 4.3536 - val_y1_output_loss: 1.2556 - val_y2_output_loss: 3.1177 - val_y1_output_root_mean_squared_error: 1.1262 - val_y2_output_root_mean_squared_error: 1.7565
# Epoch 80/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.7908 - y1_output_loss: 1.8751 - y2_output_loss: 3.8820 - y1_output_root_mean_squared_error: 1.3740 - y2_output_root_mean_squared_error: 1.9756 - val_loss: 4.1873 - val_y1_output_loss: 1.1686 - val_y2_output_loss: 3.0432 - val_y1_output_root_mean_squared_error: 1.0870 - val_y2_output_root_mean_squared_error: 1.7337
# Epoch 81/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.6907 - y1_output_loss: 1.4610 - y2_output_loss: 4.1791 - y1_output_root_mean_squared_error: 1.2143 - y2_output_root_mean_squared_error: 2.0533 - val_loss: 3.9050 - val_y1_output_loss: 1.0642 - val_y2_output_loss: 2.8403 - val_y1_output_root_mean_squared_error: 1.0334 - val_y2_output_root_mean_squared_error: 1.6844
# Epoch 82/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.3498 - y1_output_loss: 1.2671 - y2_output_loss: 3.0448 - y1_output_root_mean_squared_error: 1.1299 - y2_output_root_mean_squared_error: 1.7531 - val_loss: 3.9878 - val_y1_output_loss: 1.0916 - val_y2_output_loss: 2.8890 - val_y1_output_root_mean_squared_error: 1.0489 - val_y2_output_root_mean_squared_error: 1.6993
# Epoch 83/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.8254 - y1_output_loss: 1.2128 - y2_output_loss: 2.6345 - y1_output_root_mean_squared_error: 1.0971 - y2_output_root_mean_squared_error: 1.6192 - val_loss: 10.6566 - val_y1_output_loss: 4.1109 - val_y2_output_loss: 6.3783 - val_y1_output_root_mean_squared_error: 2.0166 - val_y2_output_root_mean_squared_error: 2.5671
# Epoch 84/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.5600 - y1_output_loss: 1.0669 - y2_output_loss: 2.4724 - y1_output_root_mean_squared_error: 1.0372 - y2_output_root_mean_squared_error: 1.5761 - val_loss: 5.5256 - val_y1_output_loss: 1.2371 - val_y2_output_loss: 4.4715 - val_y1_output_root_mean_squared_error: 1.1137 - val_y2_output_root_mean_squared_error: 2.0701
# Epoch 85/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.2602 - y1_output_loss: 0.9583 - y2_output_loss: 2.3186 - y1_output_root_mean_squared_error: 0.9665 - y2_output_root_mean_squared_error: 1.5251 - val_loss: 5.4289 - val_y1_output_loss: 2.0181 - val_y2_output_loss: 3.4546 - val_y1_output_root_mean_squared_error: 1.4172 - val_y2_output_root_mean_squared_error: 1.8494
# Epoch 86/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.0765 - y1_output_loss: 1.2528 - y2_output_loss: 3.8039 - y1_output_root_mean_squared_error: 1.1193 - y2_output_root_mean_squared_error: 1.9554 - val_loss: 4.8749 - val_y1_output_loss: 1.3961 - val_y2_output_loss: 3.4258 - val_y1_output_root_mean_squared_error: 1.1919 - val_y2_output_root_mean_squared_error: 1.8586
# Epoch 87/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.3638 - y1_output_loss: 0.8261 - y2_output_loss: 2.5148 - y1_output_root_mean_squared_error: 0.9102 - y2_output_root_mean_squared_error: 1.5923 - val_loss: 4.0462 - val_y1_output_loss: 1.0090 - val_y2_output_loss: 3.0623 - val_y1_output_root_mean_squared_error: 1.0172 - val_y2_output_root_mean_squared_error: 1.7354
# Epoch 88/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.9120 - y1_output_loss: 0.7573 - y2_output_loss: 2.1603 - y1_output_root_mean_squared_error: 0.8690 - y2_output_root_mean_squared_error: 1.4686 - val_loss: 3.6307 - val_y1_output_loss: 0.9424 - val_y2_output_loss: 2.6893 - val_y1_output_root_mean_squared_error: 0.9810 - val_y2_output_root_mean_squared_error: 1.6335
# Epoch 89/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.6089 - y1_output_loss: 1.0310 - y2_output_loss: 2.5972 - y1_output_root_mean_squared_error: 1.0183 - y2_output_root_mean_squared_error: 1.6037 - val_loss: 3.0118 - val_y1_output_loss: 0.6945 - val_y2_output_loss: 2.3558 - val_y1_output_root_mean_squared_error: 0.8447 - val_y2_output_root_mean_squared_error: 1.5160
# Epoch 90/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.2727 - y1_output_loss: 0.8187 - y2_output_loss: 2.4682 - y1_output_root_mean_squared_error: 0.9076 - y2_output_root_mean_squared_error: 1.5649 - val_loss: 6.2460 - val_y1_output_loss: 1.0397 - val_y2_output_loss: 5.1300 - val_y1_output_root_mean_squared_error: 1.0298 - val_y2_output_root_mean_squared_error: 2.2772
# Epoch 91/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.3321 - y1_output_loss: 0.8892 - y2_output_loss: 2.4664 - y1_output_root_mean_squared_error: 0.9433 - y2_output_root_mean_squared_error: 1.5628 - val_loss: 5.9448 - val_y1_output_loss: 1.4946 - val_y2_output_loss: 4.5851 - val_y1_output_root_mean_squared_error: 1.2395 - val_y2_output_root_mean_squared_error: 2.0996
# Epoch 92/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.4170 - y1_output_loss: 0.8952 - y2_output_loss: 2.4944 - y1_output_root_mean_squared_error: 0.9503 - y2_output_root_mean_squared_error: 1.5856 - val_loss: 5.7714 - val_y1_output_loss: 1.7116 - val_y2_output_loss: 4.2843 - val_y1_output_root_mean_squared_error: 1.3024 - val_y2_output_root_mean_squared_error: 2.0187
# Epoch 93/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.5227 - y1_output_loss: 1.0058 - y2_output_loss: 2.5348 - y1_output_root_mean_squared_error: 1.0030 - y2_output_root_mean_squared_error: 1.5864 - val_loss: 18.2447 - val_y1_output_loss: 5.3808 - val_y2_output_loss: 13.2601 - val_y1_output_root_mean_squared_error: 2.3232 - val_y2_output_root_mean_squared_error: 3.5843
# Epoch 94/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.2053 - y1_output_loss: 1.0320 - y2_output_loss: 3.1947 - y1_output_root_mean_squared_error: 1.0108 - y2_output_root_mean_squared_error: 1.7843 - val_loss: 8.1106 - val_y1_output_loss: 2.1971 - val_y2_output_loss: 5.7640 - val_y1_output_root_mean_squared_error: 1.4871 - val_y2_output_root_mean_squared_error: 2.4288
# Epoch 95/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.4693 - y1_output_loss: 0.8933 - y2_output_loss: 2.5640 - y1_output_root_mean_squared_error: 0.9420 - y2_output_root_mean_squared_error: 1.6068 - val_loss: 3.6508 - val_y1_output_loss: 1.0260 - val_y2_output_loss: 2.6647 - val_y1_output_root_mean_squared_error: 1.0094 - val_y2_output_root_mean_squared_error: 1.6223
# Epoch 96/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.3238 - y1_output_loss: 0.8460 - y2_output_loss: 2.5020 - y1_output_root_mean_squared_error: 0.9160 - y2_output_root_mean_squared_error: 1.5763 - val_loss: 3.3932 - val_y1_output_loss: 0.9568 - val_y2_output_loss: 2.5029 - val_y1_output_root_mean_squared_error: 0.9877 - val_y2_output_root_mean_squared_error: 1.5549
# Epoch 97/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.7569 - y1_output_loss: 1.0537 - y2_output_loss: 2.8174 - y1_output_root_mean_squared_error: 1.0305 - y2_output_root_mean_squared_error: 1.6417 - val_loss: 33.7959 - val_y1_output_loss: 3.8180 - val_y2_output_loss: 31.3763 - val_y1_output_root_mean_squared_error: 1.9307 - val_y2_output_root_mean_squared_error: 5.4835
# Epoch 98/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.4921 - y1_output_loss: 1.1274 - y2_output_loss: 3.3872 - y1_output_root_mean_squared_error: 1.0552 - y2_output_root_mean_squared_error: 1.8381 - val_loss: 6.3603 - val_y1_output_loss: 2.2229 - val_y2_output_loss: 4.2027 - val_y1_output_root_mean_squared_error: 1.4926 - val_y2_output_root_mean_squared_error: 2.0328
# Epoch 99/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.9524 - y1_output_loss: 0.7537 - y2_output_loss: 2.1795 - y1_output_root_mean_squared_error: 0.8701 - y2_output_root_mean_squared_error: 1.4817 - val_loss: 3.1477 - val_y1_output_loss: 0.6465 - val_y2_output_loss: 2.6216 - val_y1_output_root_mean_squared_error: 0.8088 - val_y2_output_root_mean_squared_error: 1.5791
# Epoch 100/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.6414 - y1_output_loss: 0.6225 - y2_output_loss: 2.0228 - y1_output_root_mean_squared_error: 0.7908 - y2_output_root_mean_squared_error: 1.4198 - val_loss: 6.0335 - val_y1_output_loss: 0.9915 - val_y2_output_loss: 5.3668 - val_y1_output_root_mean_squared_error: 0.9955 - val_y2_output_root_mean_squared_error: 2.2456
# Epoch 101/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.9551 - y1_output_loss: 0.7331 - y2_output_loss: 2.2310 - y1_output_root_mean_squared_error: 0.8574 - y2_output_root_mean_squared_error: 1.4900 - val_loss: 5.2447 - val_y1_output_loss: 1.1671 - val_y2_output_loss: 4.2496 - val_y1_output_root_mean_squared_error: 1.0793 - val_y2_output_root_mean_squared_error: 2.0198
# Epoch 102/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.8116 - y1_output_loss: 1.2361 - y2_output_loss: 3.5448 - y1_output_root_mean_squared_error: 1.1162 - y2_output_root_mean_squared_error: 1.8883 - val_loss: 2.9964 - val_y1_output_loss: 0.4922 - val_y2_output_loss: 2.6545 - val_y1_output_root_mean_squared_error: 0.7063 - val_y2_output_root_mean_squared_error: 1.5804
# Epoch 103/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.9809 - y1_output_loss: 0.7369 - y2_output_loss: 2.2384 - y1_output_root_mean_squared_error: 0.8576 - y2_output_root_mean_squared_error: 1.4985 - val_loss: 3.6400 - val_y1_output_loss: 0.5801 - val_y2_output_loss: 3.0510 - val_y1_output_root_mean_squared_error: 0.7662 - val_y2_output_root_mean_squared_error: 1.7473
# Epoch 104/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.0279 - y1_output_loss: 0.4914 - y2_output_loss: 1.5245 - y1_output_root_mean_squared_error: 0.6995 - y2_output_root_mean_squared_error: 1.2404 - val_loss: 2.8696 - val_y1_output_loss: 0.6772 - val_y2_output_loss: 2.2634 - val_y1_output_root_mean_squared_error: 0.8336 - val_y2_output_root_mean_squared_error: 1.4747
# Epoch 105/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.5441 - y1_output_loss: 0.5480 - y2_output_loss: 1.9975 - y1_output_root_mean_squared_error: 0.7430 - y2_output_root_mean_squared_error: 1.4114 - val_loss: 3.0714 - val_y1_output_loss: 0.6131 - val_y2_output_loss: 2.4701 - val_y1_output_root_mean_squared_error: 0.7926 - val_y2_output_root_mean_squared_error: 1.5631
# Epoch 106/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.1144 - y1_output_loss: 0.7233 - y2_output_loss: 2.3665 - y1_output_root_mean_squared_error: 0.8526 - y2_output_root_mean_squared_error: 1.5452 - val_loss: 3.2822 - val_y1_output_loss: 0.8122 - val_y2_output_loss: 2.5734 - val_y1_output_root_mean_squared_error: 0.9079 - val_y2_output_root_mean_squared_error: 1.5678
# Epoch 107/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.4756 - y1_output_loss: 0.6033 - y2_output_loss: 1.8583 - y1_output_root_mean_squared_error: 0.7778 - y2_output_root_mean_squared_error: 1.3677 - val_loss: 2.5054 - val_y1_output_loss: 0.5610 - val_y2_output_loss: 1.9754 - val_y1_output_root_mean_squared_error: 0.7514 - val_y2_output_root_mean_squared_error: 1.3931
# Epoch 108/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.7257 - y1_output_loss: 0.6901 - y2_output_loss: 2.0125 - y1_output_root_mean_squared_error: 0.8337 - y2_output_root_mean_squared_error: 1.4250 - val_loss: 2.6825 - val_y1_output_loss: 0.6009 - val_y2_output_loss: 2.1768 - val_y1_output_root_mean_squared_error: 0.7845 - val_y2_output_root_mean_squared_error: 1.4377
# Epoch 109/500
# 614/614 [==============================] - 0s 133us/sample - loss: 1.9581 - y1_output_loss: 0.4390 - y2_output_loss: 1.5209 - y1_output_root_mean_squared_error: 0.6639 - y2_output_root_mean_squared_error: 1.2318 - val_loss: 2.7861 - val_y1_output_loss: 0.6303 - val_y2_output_loss: 2.1876 - val_y1_output_root_mean_squared_error: 0.7961 - val_y2_output_root_mean_squared_error: 1.4671
# Epoch 110/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.8814 - y1_output_loss: 0.6889 - y2_output_loss: 2.1881 - y1_output_root_mean_squared_error: 0.8252 - y2_output_root_mean_squared_error: 1.4834 - val_loss: 2.9975 - val_y1_output_loss: 0.7272 - val_y2_output_loss: 2.2842 - val_y1_output_root_mean_squared_error: 0.8651 - val_y2_output_root_mean_squared_error: 1.4997
# Epoch 111/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.2815 - y1_output_loss: 0.5652 - y2_output_loss: 1.7244 - y1_output_root_mean_squared_error: 0.7492 - y2_output_root_mean_squared_error: 1.3116 - val_loss: 4.8620 - val_y1_output_loss: 1.4391 - val_y2_output_loss: 3.5077 - val_y1_output_root_mean_squared_error: 1.2051 - val_y2_output_root_mean_squared_error: 1.8465
# Epoch 112/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.0604 - y1_output_loss: 0.5135 - y2_output_loss: 1.5385 - y1_output_root_mean_squared_error: 0.7189 - y2_output_root_mean_squared_error: 1.2424 - val_loss: 2.4606 - val_y1_output_loss: 0.6078 - val_y2_output_loss: 1.9366 - val_y1_output_root_mean_squared_error: 0.7890 - val_y2_output_root_mean_squared_error: 1.3557
# Epoch 113/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.3820 - y1_output_loss: 1.1644 - y2_output_loss: 3.2129 - y1_output_root_mean_squared_error: 1.0739 - y2_output_root_mean_squared_error: 1.7969 - val_loss: 8.0700 - val_y1_output_loss: 1.6671 - val_y2_output_loss: 6.6137 - val_y1_output_root_mean_squared_error: 1.2985 - val_y2_output_root_mean_squared_error: 2.5266
# Epoch 114/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.1115 - y1_output_loss: 0.5551 - y2_output_loss: 1.5384 - y1_output_root_mean_squared_error: 0.7486 - y2_output_root_mean_squared_error: 1.2454 - val_loss: 2.7502 - val_y1_output_loss: 0.5490 - val_y2_output_loss: 2.2323 - val_y1_output_root_mean_squared_error: 0.7448 - val_y2_output_root_mean_squared_error: 1.4817
# Epoch 115/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.2782 - y1_output_loss: 0.5975 - y2_output_loss: 1.6888 - y1_output_root_mean_squared_error: 0.7739 - y2_output_root_mean_squared_error: 1.2959 - val_loss: 3.6825 - val_y1_output_loss: 0.7375 - val_y2_output_loss: 2.8919 - val_y1_output_root_mean_squared_error: 0.8634 - val_y2_output_root_mean_squared_error: 1.7138
# Epoch 116/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.6878 - y1_output_loss: 0.6348 - y2_output_loss: 2.0405 - y1_output_root_mean_squared_error: 0.7972 - y2_output_root_mean_squared_error: 1.4326 - val_loss: 3.3132 - val_y1_output_loss: 0.7327 - val_y2_output_loss: 2.6100 - val_y1_output_root_mean_squared_error: 0.8568 - val_y2_output_root_mean_squared_error: 1.6059
# Epoch 117/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.3354 - y1_output_loss: 0.5890 - y2_output_loss: 1.7431 - y1_output_root_mean_squared_error: 0.7690 - y2_output_root_mean_squared_error: 1.3206 - val_loss: 3.9788 - val_y1_output_loss: 1.1906 - val_y2_output_loss: 2.8438 - val_y1_output_root_mean_squared_error: 1.1014 - val_y2_output_root_mean_squared_error: 1.6630
# Epoch 118/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.1182 - y1_output_loss: 0.4919 - y2_output_loss: 1.6226 - y1_output_root_mean_squared_error: 0.6967 - y2_output_root_mean_squared_error: 1.2778 - val_loss: 4.2391 - val_y1_output_loss: 0.8080 - val_y2_output_loss: 3.4179 - val_y1_output_root_mean_squared_error: 0.8948 - val_y2_output_root_mean_squared_error: 1.8543
# Epoch 119/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.1516 - y1_output_loss: 0.4545 - y2_output_loss: 1.6860 - y1_output_root_mean_squared_error: 0.6728 - y2_output_root_mean_squared_error: 1.3034 - val_loss: 2.2680 - val_y1_output_loss: 0.4968 - val_y2_output_loss: 1.8370 - val_y1_output_root_mean_squared_error: 0.7059 - val_y2_output_root_mean_squared_error: 1.3303
# Epoch 120/500
# 614/614 [==============================] - 0s 138us/sample - loss: 1.8143 - y1_output_loss: 0.4238 - y2_output_loss: 1.4401 - y1_output_root_mean_squared_error: 0.6528 - y2_output_root_mean_squared_error: 1.1782 - val_loss: 8.8562 - val_y1_output_loss: 1.3785 - val_y2_output_loss: 7.9387 - val_y1_output_root_mean_squared_error: 1.1775 - val_y2_output_root_mean_squared_error: 2.7331
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4600 - y1_output_loss: 0.1284 - y2_output_loss: 0.3342 - y1_output_root_mean_squared_error: 0.3582 - y2_output_root_mean_squared_error: 0.5759 - val_loss: 1.4065 - val_y1_output_loss: 0.2617 - val_y2_output_loss: 1.1584 - val_y1_output_root_mean_squared_error: 0.5171 - val_y2_output_root_mean_squared_error: 1.0673
# Epoch 462/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.9118 - y1_output_loss: 0.1952 - y2_output_loss: 0.7098 - y1_output_root_mean_squared_error: 0.4424 - y2_output_root_mean_squared_error: 0.8462 - val_loss: 1.2655 - val_y1_output_loss: 0.3209 - val_y2_output_loss: 0.9540 - val_y1_output_root_mean_squared_error: 0.5753 - val_y2_output_root_mean_squared_error: 0.9667
# Epoch 463/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3869 - y1_output_loss: 0.1189 - y2_output_loss: 0.2672 - y1_output_root_mean_squared_error: 0.3438 - y2_output_root_mean_squared_error: 0.5183 - val_loss: 0.8526 - val_y1_output_loss: 0.2439 - val_y2_output_loss: 0.6629 - val_y1_output_root_mean_squared_error: 0.5027 - val_y2_output_root_mean_squared_error: 0.7746
# Epoch 464/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3800 - y1_output_loss: 0.1131 - y2_output_loss: 0.2664 - y1_output_root_mean_squared_error: 0.3363 - y2_output_root_mean_squared_error: 0.5166 - val_loss: 0.9619 - val_y1_output_loss: 0.2499 - val_y2_output_loss: 0.7650 - val_y1_output_root_mean_squared_error: 0.5041 - val_y2_output_root_mean_squared_error: 0.8413
# Epoch 465/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.4705 - y1_output_loss: 0.1355 - y2_output_loss: 0.3345 - y1_output_root_mean_squared_error: 0.3684 - y2_output_root_mean_squared_error: 0.5786 - val_loss: 1.1732 - val_y1_output_loss: 0.2751 - val_y2_output_loss: 0.9254 - val_y1_output_root_mean_squared_error: 0.5315 - val_y2_output_root_mean_squared_error: 0.9438
# Epoch 466/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3455 - y1_output_loss: 0.0995 - y2_output_loss: 0.2490 - y1_output_root_mean_squared_error: 0.3144 - y2_output_root_mean_squared_error: 0.4966 - val_loss: 1.1472 - val_y1_output_loss: 0.2686 - val_y2_output_loss: 0.9130 - val_y1_output_root_mean_squared_error: 0.5255 - val_y2_output_root_mean_squared_error: 0.9333
# Epoch 467/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4085 - y1_output_loss: 0.1107 - y2_output_loss: 0.2979 - y1_output_root_mean_squared_error: 0.3318 - y2_output_root_mean_squared_error: 0.5463 - val_loss: 1.7057 - val_y1_output_loss: 0.4133 - val_y2_output_loss: 1.2874 - val_y1_output_root_mean_squared_error: 0.6482 - val_y2_output_root_mean_squared_error: 1.1338
# Epoch 468/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4471 - y1_output_loss: 0.1209 - y2_output_loss: 0.3266 - y1_output_root_mean_squared_error: 0.3470 - y2_output_root_mean_squared_error: 0.5716 - val_loss: 1.3707 - val_y1_output_loss: 0.3702 - val_y2_output_loss: 1.0251 - val_y1_output_root_mean_squared_error: 0.6072 - val_y2_output_root_mean_squared_error: 1.0010
# Epoch 469/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4468 - y1_output_loss: 0.1224 - y2_output_loss: 0.3248 - y1_output_root_mean_squared_error: 0.3500 - y2_output_root_mean_squared_error: 0.5695 - val_loss: 0.8182 - val_y1_output_loss: 0.2415 - val_y2_output_loss: 0.6323 - val_y1_output_root_mean_squared_error: 0.4995 - val_y2_output_root_mean_squared_error: 0.7542
# Epoch 470/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3501 - y1_output_loss: 0.0971 - y2_output_loss: 0.2540 - y1_output_root_mean_squared_error: 0.3112 - y2_output_root_mean_squared_error: 0.5032 - val_loss: 1.0536 - val_y1_output_loss: 0.3020 - val_y2_output_loss: 0.8031 - val_y1_output_root_mean_squared_error: 0.5536 - val_y2_output_root_mean_squared_error: 0.8643
# Epoch 471/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3144 - y1_output_loss: 0.0955 - y2_output_loss: 0.2177 - y1_output_root_mean_squared_error: 0.3094 - y2_output_root_mean_squared_error: 0.4677 - val_loss: 0.8714 - val_y1_output_loss: 0.2684 - val_y2_output_loss: 0.6368 - val_y1_output_root_mean_squared_error: 0.5236 - val_y2_output_root_mean_squared_error: 0.7728
# Epoch 472/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3505 - y1_output_loss: 0.1104 - y2_output_loss: 0.2376 - y1_output_root_mean_squared_error: 0.3336 - y2_output_root_mean_squared_error: 0.4891 - val_loss: 0.9427 - val_y1_output_loss: 0.2468 - val_y2_output_loss: 0.7305 - val_y1_output_root_mean_squared_error: 0.5016 - val_y2_output_root_mean_squared_error: 0.8313
# Epoch 473/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3539 - y1_output_loss: 0.1185 - y2_output_loss: 0.2385 - y1_output_root_mean_squared_error: 0.3417 - y2_output_root_mean_squared_error: 0.4870 - val_loss: 1.4587 - val_y1_output_loss: 0.3227 - val_y2_output_loss: 1.1711 - val_y1_output_root_mean_squared_error: 0.5687 - val_y2_output_root_mean_squared_error: 1.0655
# Epoch 474/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4151 - y1_output_loss: 0.1251 - y2_output_loss: 0.2884 - y1_output_root_mean_squared_error: 0.3523 - y2_output_root_mean_squared_error: 0.5394 - val_loss: 0.8576 - val_y1_output_loss: 0.2539 - val_y2_output_loss: 0.6457 - val_y1_output_root_mean_squared_error: 0.5128 - val_y2_output_root_mean_squared_error: 0.7711
# Epoch 475/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4094 - y1_output_loss: 0.1184 - y2_output_loss: 0.2910 - y1_output_root_mean_squared_error: 0.3453 - y2_output_root_mean_squared_error: 0.5387 - val_loss: 0.9517 - val_y1_output_loss: 0.2233 - val_y2_output_loss: 0.7804 - val_y1_output_root_mean_squared_error: 0.4792 - val_y2_output_root_mean_squared_error: 0.8497
# Epoch 476/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3568 - y1_output_loss: 0.1161 - y2_output_loss: 0.2408 - y1_output_root_mean_squared_error: 0.3392 - y2_output_root_mean_squared_error: 0.4917 - val_loss: 0.8458 - val_y1_output_loss: 0.2509 - val_y2_output_loss: 0.6479 - val_y1_output_root_mean_squared_error: 0.5092 - val_y2_output_root_mean_squared_error: 0.7659
# Epoch 477/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3923 - y1_output_loss: 0.1097 - y2_output_loss: 0.2830 - y1_output_root_mean_squared_error: 0.3321 - y2_output_root_mean_squared_error: 0.5310 - val_loss: 1.1601 - val_y1_output_loss: 0.2863 - val_y2_output_loss: 0.9016 - val_y1_output_root_mean_squared_error: 0.5387 - val_y2_output_root_mean_squared_error: 0.9326
# Epoch 478/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3799 - y1_output_loss: 0.1053 - y2_output_loss: 0.2766 - y1_output_root_mean_squared_error: 0.3247 - y2_output_root_mean_squared_error: 0.5239 - val_loss: 0.8957 - val_y1_output_loss: 0.2781 - val_y2_output_loss: 0.6573 - val_y1_output_root_mean_squared_error: 0.5358 - val_y2_output_root_mean_squared_error: 0.7802
# Epoch 479/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3446 - y1_output_loss: 0.1005 - y2_output_loss: 0.2441 - y1_output_root_mean_squared_error: 0.3182 - y2_output_root_mean_squared_error: 0.4933 - val_loss: 1.1768 - val_y1_output_loss: 0.2717 - val_y2_output_loss: 0.9931 - val_y1_output_root_mean_squared_error: 0.5294 - val_y2_output_root_mean_squared_error: 0.9469
# Epoch 480/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.5158 - y1_output_loss: 0.1383 - y2_output_loss: 0.3741 - y1_output_root_mean_squared_error: 0.3735 - y2_output_root_mean_squared_error: 0.6134 - val_loss: 1.1098 - val_y1_output_loss: 0.2481 - val_y2_output_loss: 0.8699 - val_y1_output_root_mean_squared_error: 0.5048 - val_y2_output_root_mean_squared_error: 0.9247
# Epoch 481/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.5294 - y1_output_loss: 0.1361 - y2_output_loss: 0.3925 - y1_output_root_mean_squared_error: 0.3692 - y2_output_root_mean_squared_error: 0.6269 - val_loss: 1.1017 - val_y1_output_loss: 0.3059 - val_y2_output_loss: 0.8646 - val_y1_output_root_mean_squared_error: 0.5621 - val_y2_output_root_mean_squared_error: 0.8864
# Epoch 482/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3944 - y1_output_loss: 0.1277 - y2_output_loss: 0.2710 - y1_output_root_mean_squared_error: 0.3555 - y2_output_root_mean_squared_error: 0.5177 - val_loss: 1.1029 - val_y1_output_loss: 0.2695 - val_y2_output_loss: 0.8704 - val_y1_output_root_mean_squared_error: 0.5274 - val_y2_output_root_mean_squared_error: 0.9082
# Epoch 483/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3502 - y1_output_loss: 0.0996 - y2_output_loss: 0.2492 - y1_output_root_mean_squared_error: 0.3166 - y2_output_root_mean_squared_error: 0.5000 - val_loss: 0.8240 - val_y1_output_loss: 0.2445 - val_y2_output_loss: 0.6281 - val_y1_output_root_mean_squared_error: 0.5030 - val_y2_output_root_mean_squared_error: 0.7556
# Epoch 484/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3562 - y1_output_loss: 0.1115 - y2_output_loss: 0.2480 - y1_output_root_mean_squared_error: 0.3285 - y2_output_root_mean_squared_error: 0.4983 - val_loss: 1.2317 - val_y1_output_loss: 0.3826 - val_y2_output_loss: 0.8891 - val_y1_output_root_mean_squared_error: 0.6246 - val_y2_output_root_mean_squared_error: 0.9174
# Epoch 485/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3770 - y1_output_loss: 0.1094 - y2_output_loss: 0.2700 - y1_output_root_mean_squared_error: 0.3301 - y2_output_root_mean_squared_error: 0.5177 - val_loss: 1.6719 - val_y1_output_loss: 0.2594 - val_y2_output_loss: 1.4387 - val_y1_output_root_mean_squared_error: 0.5132 - val_y2_output_root_mean_squared_error: 1.1868
# Epoch 486/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3554 - y1_output_loss: 0.1094 - y2_output_loss: 0.2467 - y1_output_root_mean_squared_error: 0.3290 - y2_output_root_mean_squared_error: 0.4971 - val_loss: 1.5136 - val_y1_output_loss: 0.3398 - val_y2_output_loss: 1.2039 - val_y1_output_root_mean_squared_error: 0.5844 - val_y2_output_root_mean_squared_error: 1.0826
# Epoch 487/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3961 - y1_output_loss: 0.1248 - y2_output_loss: 0.2678 - y1_output_root_mean_squared_error: 0.3545 - y2_output_root_mean_squared_error: 0.5200 - val_loss: 0.9075 - val_y1_output_loss: 0.2513 - val_y2_output_loss: 0.7032 - val_y1_output_root_mean_squared_error: 0.5105 - val_y2_output_root_mean_squared_error: 0.8043
# Epoch 488/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3693 - y1_output_loss: 0.0994 - y2_output_loss: 0.2673 - y1_output_root_mean_squared_error: 0.3164 - y2_output_root_mean_squared_error: 0.5188 - val_loss: 0.8569 - val_y1_output_loss: 0.2495 - val_y2_output_loss: 0.6345 - val_y1_output_root_mean_squared_error: 0.5064 - val_y2_output_root_mean_squared_error: 0.7748
# Epoch 489/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4158 - y1_output_loss: 0.1123 - y2_output_loss: 0.3009 - y1_output_root_mean_squared_error: 0.3348 - y2_output_root_mean_squared_error: 0.5511 - val_loss: 0.8851 - val_y1_output_loss: 0.2881 - val_y2_output_loss: 0.6280 - val_y1_output_root_mean_squared_error: 0.5435 - val_y2_output_root_mean_squared_error: 0.7679
# Epoch 490/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.5332 - y1_output_loss: 0.1392 - y2_output_loss: 0.3904 - y1_output_root_mean_squared_error: 0.3736 - y2_output_root_mean_squared_error: 0.6274 - val_loss: 0.8398 - val_y1_output_loss: 0.2379 - val_y2_output_loss: 0.6430 - val_y1_output_root_mean_squared_error: 0.4939 - val_y2_output_root_mean_squared_error: 0.7720
# Epoch 491/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3622 - y1_output_loss: 0.1075 - y2_output_loss: 0.2563 - y1_output_root_mean_squared_error: 0.3271 - y2_output_root_mean_squared_error: 0.5052 - val_loss: 1.2945 - val_y1_output_loss: 0.3425 - val_y2_output_loss: 0.9588 - val_y1_output_root_mean_squared_error: 0.5945 - val_y2_output_root_mean_squared_error: 0.9700
# Epoch 492/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3593 - y1_output_loss: 0.1172 - y2_output_loss: 0.2401 - y1_output_root_mean_squared_error: 0.3433 - y2_output_root_mean_squared_error: 0.4914 - val_loss: 0.9115 - val_y1_output_loss: 0.2296 - val_y2_output_loss: 0.7489 - val_y1_output_root_mean_squared_error: 0.4873 - val_y2_output_root_mean_squared_error: 0.8210
# Epoch 493/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3891 - y1_output_loss: 0.1110 - y2_output_loss: 0.2763 - y1_output_root_mean_squared_error: 0.3345 - y2_output_root_mean_squared_error: 0.5265 - val_loss: 0.9224 - val_y1_output_loss: 0.2383 - val_y2_output_loss: 0.7375 - val_y1_output_root_mean_squared_error: 0.4965 - val_y2_output_root_mean_squared_error: 0.8221
# Epoch 494/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3833 - y1_output_loss: 0.1084 - y2_output_loss: 0.2764 - y1_output_root_mean_squared_error: 0.3301 - y2_output_root_mean_squared_error: 0.5238 - val_loss: 1.7984 - val_y1_output_loss: 0.2824 - val_y2_output_loss: 1.5162 - val_y1_output_root_mean_squared_error: 0.5371 - val_y2_output_root_mean_squared_error: 1.2288
# Epoch 495/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3145 - y1_output_loss: 0.1092 - y2_output_loss: 0.2061 - y1_output_root_mean_squared_error: 0.3310 - y2_output_root_mean_squared_error: 0.4527 - val_loss: 1.0090 - val_y1_output_loss: 0.2488 - val_y2_output_loss: 0.7813 - val_y1_output_root_mean_squared_error: 0.5056 - val_y2_output_root_mean_squared_error: 0.8680
# Epoch 496/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4824 - y1_output_loss: 0.1216 - y2_output_loss: 0.3652 - y1_output_root_mean_squared_error: 0.3495 - y2_output_root_mean_squared_error: 0.6003 - val_loss: 1.0363 - val_y1_output_loss: 0.2576 - val_y2_output_loss: 0.8329 - val_y1_output_root_mean_squared_error: 0.5164 - val_y2_output_root_mean_squared_error: 0.8773
# Epoch 497/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3159 - y1_output_loss: 0.1021 - y2_output_loss: 0.2179 - y1_output_root_mean_squared_error: 0.3174 - y2_output_root_mean_squared_error: 0.4638 - val_loss: 1.8921 - val_y1_output_loss: 0.4375 - val_y2_output_loss: 1.4702 - val_y1_output_root_mean_squared_error: 0.6617 - val_y2_output_root_mean_squared_error: 1.2059
# Epoch 498/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3589 - y1_output_loss: 0.1145 - y2_output_loss: 0.2426 - y1_output_root_mean_squared_error: 0.3389 - y2_output_root_mean_squared_error: 0.4940 - val_loss: 0.7770 - val_y1_output_loss: 0.2276 - val_y2_output_loss: 0.5804 - val_y1_output_root_mean_squared_error: 0.4853 - val_y2_output_root_mean_squared_error: 0.7358
# Epoch 499/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3229 - y1_output_loss: 0.1004 - y2_output_loss: 0.2200 - y1_output_root_mean_squared_error: 0.3177 - y2_output_root_mean_squared_error: 0.4711 - val_loss: 0.8429 - val_y1_output_loss: 0.2734 - val_y2_output_loss: 0.6246 - val_y1_output_root_mean_squared_error: 0.5306 - val_y2_output_root_mean_squared_error: 0.7493
# Epoch 500/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3450 - y1_output_loss: 0.1101 - y2_output_loss: 0.2340 - y1_output_root_mean_squared_error: 0.3312 - y2_output_root_mean_squared_error: 0.4851 - val_loss: 0.7687 - val_y1_output_loss: 0.2327 - val_y2_output_loss: 0.5725 - val_y1_output_root_mean_squared_error: 0.4898 - val_y2_output_root_mean_squared_error: 0.7272

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 32us/sample - loss: 0.7687 - y1_output_loss: 0.2357 - y2_output_loss: 0.5263 - y1_output_root_mean_squared_error: 0.4898 - y2_output_root_mean_squared_error: 0.7272
# Loss = 0.76870256197917, Y1_loss = 0.23566076159477234, Y1_mse = 0.48977020382881165, Y2_loss = 0.5263217687606812, Y2_mse = 0.7272053956985474

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
